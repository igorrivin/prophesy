# %%
from prostrat import *
util.startLoop()
profinit(12, socknum=7498)
# Out:
# INFO:ib_insync.client:Connecting to 127.0.0.1:7498 with clientId 12...
# INFO:ib_insync.client:Disconnecting
# ERROR:ib_insync.client:API connection failed: ConnectionRefusedError(111, "Connect call failed ('127.0.0.1', 7498)")
# ERROR:ib_insync.client:Make sure API port on TWS/IBG is open
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-1-7fe9f47fc964> in <module>
#       1 from prostrat import *
#       2 util.startLoop()
# ----> 3 profinit(12, socknum=7498)
#
# ~/devel/prophesy/prostrat.py in profinit(idnum, ipaddr, socknum)
#       9
#      10 def profinit(idnum,  ipaddr='127.0.0.1', socknum=7497):
# ---> 11     ib.connect(ipaddr, socknum, clientId=idnum)
#      12
#      13 def doprof(contract, hist='50 D', freq='1 hour', freq2='1H', lookahead=24, include_history=True):
#
# ...

# %%
contract = Future('MES', '201909', 'GLOBEX')

# %%
from time import sleep

# %%
oldwait=10
while True:
    oldwait=protrader(contract, 0.0012,waittime=oldwait, holdtime=600, incwait=100)
    print(oldwait)
    sleep(oldwait)
