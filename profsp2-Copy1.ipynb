# %%
from prostrat import *

# %%
profinit(14, socknum=4001)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-6e50a323a609> in <module>
# ----> 1 profinit(14, socknum=4001)
#
# ~/devel/prophesy/prostrat.py in profinit(idnum, ipaddr, socknum)
#       8
#       9 def profinit(idnum,  ipaddr='127.0.0.1', socknum=7497):
# ---> 10     ib.connect(ipaddr, socknum, clientId=idnum)
#      11
#      12 def doprof(contract, hist='50 D', freq='1 hour', freq2='1H', lookahead=24, include_history=True):
#
# ~/anaconda3/envs/proph/lib/python3.7/site-packages/ib_insync/ib.py in connect(self, host, port, clientId, timeout, readonly)
#     228         """
#     229         return self._run(self.connectAsync(
# --> 230             host, port, clientId, timeout, readonly))
#     231
#     232     def disconnect(self):
#
# ~/anaconda3/envs/proph/lib/python3.7/site-packages/ib_insync/ib.py in _run(self, *awaitables)
#     261
# ...

# %%
sptab = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# %%
util.startLoop()

# %%
symbols= list(sptab.Symbol)

# %%
preddict = {}

# %%
for i in symbols:
    try:
        preddict[i] = doprof(Stock(i, 'SMART', 'USD'))
    except:
        pass
# Out:
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
profinit(14, socknum=7496)

# %%
doprof(Stock('TSLA', 'SMART', 'USD'), hist='50 D', freq='1 hour', freq2='1H', lookahead=24, include_history=True)

# %%
contract = Stock('MMM', 'SMART', 'USD')

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='50 D',
        barSizeSetting='1 hour',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)

# %%
bars

# %%
preddict.values()

# %%
preddict

# %%
from operator import itemgetter
sdict=sorted(preddict.items(), key=itemgetter(1))

# %%
sdict
# Out:
# [('BIIB', -0.0677520856311018),
#  ('CNC', -0.0668780205946291),
#  ('NEM', -0.06209815428164722),
#  ('WCG', -0.04164250945637793),
#  ('IRM', -0.04125572585931003),
#  ('WAT', -0.03806299319977491),
#  ('ANTM', -0.03663925934063439),
#  ('UNH', -0.0347110493281928),
#  ('MAC', -0.03389506755341065),
#  ('GE', -0.0321727360303794),
#  ('NKTR', -0.03196283448324744),
#  ('HCP', -0.028954312655395942),
#  ('PNW', -0.028623357464906185),
#  ('WBA', -0.025672583376833646),
#  ('VTR', -0.02544707955810832),
#  ('PPL', -0.02433671021459416),
#  ('SRE', -0.022314442648287525),
#  ('HRL', -0.021977789826130856),
#  ('PSX', -0.021160471958569183),
#  ('KIM', -0.020833103490003335),
#  ('AWK', -0.020081062650779913),
#  ('SPG', -0.02002361459123314),
#  ('COTY', -0.01993652239461463),
#  ('NWL', -0.019912866293867015),
#  ('MMM', -0.019259453471929255),
#  ('LIN', -0.01922612662892753),
#  ('CMS', -0.01884030127512748),
#  ('NEE', -0.018780625370657944),
#  ('CI', -0.018705589826559788),
# ...
