# %%
from prostrat import *

# %%
sptab = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# %%
symbols= list(sptab.Symbol)

# %%
preddict = {}

# %%
for i in symbols:
    try:
        preddict[i] = doprof(Stock(i, 'SMART', 'USD'))
    except:
        pass
# Out:
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/igor/anaconda3/envs/proph/lib/python3.7/site-packages/fbprophet/forecaster.py:880: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   min_dt = dt.iloc[dt.nonzero()[0]].min()
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.27000045, marketValue=-821.6, averageCost=10.22876875, unrealizedPNL=-3.3, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.22999955, marketValue=1004.6, averageCost=50.7085, unrealizedPNL=-9.57, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=248.91999815, marketValue=-1244.6, averageCost=253.79642, unrealizedPNL=24.38, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.26600075, marketValue=-821.28, averageCost=10.22876875, unrealizedPNL=-2.98, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.2740021, marketValue=1005.48, averageCost=50.7085, unrealizedPNL=-8.69, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=248.71836855, marketValue=-1243.59, averageCost=253.79642, unrealizedPNL=25.39, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.29399965, marketValue=-823.52, averageCost=10.22876875, unrealizedPNL=-5.22, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.36400225, marketValue=1007.28, averageCost=50.7085, unrealizedPNL=-6.89, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=249.46385195, marketValue=-1247.32, averageCost=253.79642, unrealizedPNL=21.66, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.28600025, marketValue=-822.88, averageCost=10.22876875, unrealizedPNL=-4.58, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.2860985, marketValue=1005.72, averageCost=50.7085, unrealizedPNL=-8.45, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=249.5782013, marketValue=-1247.89, averageCost=253.79642, unrealizedPNL=21.09, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.276, marketValue=-822.08, averageCost=10.22876875, unrealizedPNL=-3.78, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.3639984, marketValue=1007.28, averageCost=50.7085, unrealizedPNL=-6.89, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.4901123, marketValue=-1252.45, averageCost=253.79642, unrealizedPNL=16.53, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.3239975, marketValue=1006.48, averageCost=50.7085, unrealizedPNL=-7.69, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.1838684, marketValue=-1250.92, averageCost=253.79642, unrealizedPNL=18.06, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.28399945, marketValue=-822.72, averageCost=10.22876875, unrealizedPNL=-4.42, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.3959999, marketValue=1007.92, averageCost=50.7085, unrealizedPNL=-6.25, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.1177368, marketValue=-1250.59, averageCost=253.79642, unrealizedPNL=18.39, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.27609635, marketValue=-822.09, averageCost=10.22876875, unrealizedPNL=-3.79, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.40399935, marketValue=1008.08, averageCost=50.7085, unrealizedPNL=-6.09, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=249.7096863, marketValue=-1248.55, averageCost=253.79642, unrealizedPNL=20.43, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.26600075, marketValue=-821.28, averageCost=10.22876875, unrealizedPNL=-2.98, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.45399855, marketValue=1009.08, averageCost=50.7085, unrealizedPNL=-5.09, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=249.72639465, marketValue=-1248.63, averageCost=253.79642, unrealizedPNL=20.35, realizedPNL=0.0, account='U2578504')

# %%
util.startLoop()

# %%
profinit(14, socknum=7496)
# Out:
# INFO:ib_insync.client:Connecting to 127.0.0.1:7496 with clientId 14...
# INFO:ib_insync.client:Connected
# INFO:ib_insync.client:Logged on to server version 151
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:hfarm
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:usfarm.nj
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:jfarm
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:eufarm
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:usfuture
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:cashfarm
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:usopt
# INFO:ib_insync.wrapper:Warning 2104, reqId -1: Market data farm connection is OK:usfarm
# INFO:ib_insync.wrapper:Warning 2106, reqId -1: HMDS data farm connection is OK:euhmds
# INFO:ib_insync.wrapper:Warning 2106, reqId -1: HMDS data farm connection is OK:fundfarm
# INFO:ib_insync.wrapper:Warning 2106, reqId -1: HMDS data farm connection is OK:ushmds
# INFO:ib_insync.client:API connection ready
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.28600025, marketValue=-822.88, averageCost=10.22876875, unrealizedPNL=-4.58, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.3160019, marketValue=1006.32, averageCost=50.7085, unrealizedPNL=-7.85, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.5041809, marketValue=-1252.52, averageCost=253.79642, unrealizedPNL=16.46, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=7516, symbol='GE', exchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, avgCost=10.22876875)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=76792991, symbol='TSLA', exchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, avgCost=253.79642)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=270639, symbol='INTC', exchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, avgCost=50.7085)
# INFO:ib_insync.ib:Synchronization complete
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.276, marketValue=-822.08, averageCost=10.22876875, unrealizedPNL=-3.78, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.2739029, marketValue=1005.48, averageCost=50.7085, unrealizedPNL=-8.69, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.57063295, marketValue=-1252.85, averageCost=253.79642, unrealizedPNL=16.13, realizedPNL=0.0, account='U2578504')

# %%
doprof(Stock('TSLA', 'SMART', 'USD'), hist='50 D', freq='1 hour', freq2='1H', lookahead=24, include_history=True)

# %%
contract = Stock('MMM', 'SMART', 'USD')

# %%
bars = ib.reqHistoricalData(
        contract,
        endDateTime='',
        durationStr='50 D',
        barSizeSetting='1 hour',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)

# %%
bars

# %%
preddict.values()

# %%
preddict

# %%
from operator import itemgetter
sdict=sorted(preddict.items(), key=itemgetter(1))

# %%
sdict
# Out:
# [('CNC', -0.1280505667398013),
#  ('NWL', -0.1055426896587992),
#  ('BIIB', -0.09443525446852696),
#  ('INCY', -0.08847358231755553),
#  ('GE', -0.08603783456195924),
#  ('COTY', -0.08599043601973921),
#  ('ANTM', -0.06269096013438613),
#  ('ABC', -0.05793331553436509),
#  ('WBA', -0.05531194275275508),
#  ('XRAY', -0.054747021924201444),
#  ('AIG', -0.053390854991031134),
#  ('HSIC', -0.04985792175890058),
#  ('MCK', -0.04908033624359476),
#  ('UNH', -0.047279930334298115),
#  ('WAT', -0.04631352655328058),
#  ('APC', -0.046002589324509735),
#  ('HCA', -0.04543663476101756),
#  ('RMD', -0.044038161292849765),
#  ('IDXX', -0.043534062606402024),
#  ('AIZ', -0.042611856294541006),
#  ('TFX', -0.03931900265531141),
#  ('ABMD', -0.03930741491552503),
#  ('KIM', -0.0353200478751976),
#  ('DVA', -0.03349407556303685),
#  ('MRK', -0.03279891161837334),
#  ('CAH', -0.03126226450380232),
#  ('TRIP', -0.031152143059628656),
#  ('NKTR', -0.03112775788691513),
#  ('EW', -0.031024802268185603),
#  ('BSX', -0.030463379566948223),
#  ('VTR', -0.028311194667432815),
#  ('CI', -0.026950203849707144),
#  ('CMG', -0.026767569040965),
#  ('OXY', -0.026548475686021256),
#  ('LH', -0.02626860716949242),
#  ('TTWO', -0.02554465967200592),
#  ('ISRG', -0.025320071255251264),
#  ('MNST', -0.02414065097581286),
#  ('GILD', -0.024115932289941355),
#  ('CVS', -0.024025925169270934),
#  ('HOLX', -0.023185949588339305),
#  ('BAX', -0.02300470922494302),
#  ('VRTX', -0.022880991496328384),
#  ('SYY', -0.021886252443295007),
#  ('NEM', -0.02072339806298773),
#  ('MAC', -0.01983276654374455),
#  ('KEY', -0.0192101497073196),
#  ('PFE', -0.0187304499976495),
#  ('BLL', -0.018360456280521298),
#  ('ZBH', -0.018276624221404525),
#  ('A', -0.01782384512120494),
#  ('ARNC', -0.017744741162811994),
#  ('EQIX', -0.017511108154734778),
#  ('BMY', -0.016189524270575628),
#  ('FBHS', -0.015561868940622503),
#  ('RE', -0.015160718528050232),
#  ('JBHT', -0.01480263918392044),
#  ('ILMN', -0.013696699028215242),
#  ('GPC', -0.01266319429580065),
#  ('HUM', -0.012504147296273693),
#  ('HCP', -0.011879347155715703),
#  ('BDX', -0.011743368776332197),
#  ('HRL', -0.011702017590677904),
#  ('AIV', -0.011505959957455403),
#  ('QCOM', -0.011449066153955023),
#  ('SYK', -0.011421092220139428),
#  ('ALB', -0.011248658168690362),
#  ('DGX', -0.010668110956267185),
#  ('PKI', -0.010523922528569152),
#  ('DRI', -0.010441161500344798),
#  ('ORLY', -0.01022225124240883),
#  ('MET', -0.01013095270559683),
#  ('STX', -0.009815723207176053),
#  ('TMO', -0.009788438383911746),
#  ('SPG', -0.009677072446777402),
#  ('EA', -0.009602144879514718),
#  ('CME', -0.009592106063978534),
#  ('FMC', -0.009509073290052683),
#  ('AZO', -0.00931970155369477),
#  ('WRK', -0.009240867063486036),
#  ('VAR', -0.009106907238491502),
#  ('LLY', -0.008986444909202085),
#  ('NI', -0.008955739449627576),
#  ('AMGN', -0.008831266161663187),
#  ('ROL', -0.00875833712361862),
#  ('JWN', -0.007717856901610087),
#  ('TSN', -0.007658479131936957),
#  ('ABT', -0.007627164650510387),
#  ('LW', -0.007167637256793036),
#  ('PPL', -0.006351849454751424),
#  ('SBUX', -0.006116996007415665),
#  ('ALGN', -0.006085633658929446),
#  ('FISV', -0.006037281838523256),
#  ('IQV', -0.005365527538358172),
#  ('COO', -0.005136900493697638),
#  ('MHK', -0.004600445653568208),
#  ('MTD', -0.004233864189644443),
#  ('REGN', -0.004175105975666504),
#  ('XEL', -0.004034271247088661),
#  ('DLR', -0.003903334007290482),
#  ('RHT', -0.0034963500296472105),
#  ('MCD', -0.0031862743252242254),
#  ('WEC', -0.003002566404346929),
#  ('EVRG', -0.0029963375861612462),
#  ('VZ', -0.002397408317724725),
#  ('TGT', -0.0023894038890732716),
#  ('HLT', -0.002167342863614863),
#  ('ABBV', -0.001993341079332467),
#  ('MKC', -0.00185806566055291),
#  ('HRS', -0.0015289508847509126),
#  ('FIS', -0.0013903678333981873),
#  ('CVX', -0.0013409934085411024),
#  ('CBOE', -0.0012239942222889155),
#  ('PNR', -0.0010697340674088451),
#  ('RF', -0.0008478981684048037),
#  ('RCL', -0.0008378920570732973),
#  ('HST', -0.0008377117545097512),
#  ('AAP', -0.0005937143473904172),
#  ('WMT', -1.1023437579638085e-05),
#  ('CNP', 7.050762702798252e-05),
#  ('ES', 0.0003816314803435361),
#  ('CMS', 0.0004509034707593784),
#  ('AGN', 0.0009163743834355031),
#  ('DTE', 0.0009509557535380964),
#  ('MAS', 0.0011797331013285728),
#  ('IP', 0.0012207087275943884),
#  ('ALXN', 0.0013334423857775946),
#  ('MO', 0.001508345671006328),
#  ('LNT', 0.0015136252092249336),
#  ('MMM', 0.001539345201566178),
#  ('RTN', 0.0015688672918789948),
#  ('AEE', 0.0016464628439250006),
#  ('FITB', 0.0016700528972277695),
#  ('MDT', 0.0017662635695572249),
#  ('SO', 0.0018899081103862514),
#  ('FE', 0.0019760364052996415),
#  ('KEYS', 0.002364761705310414),
#  ('LLL', 0.002367595378570009),
#  ('UHS', 0.0024292232486446963),
#  ('PEG', 0.002594408900354672),
#  ('TDG', 0.002795492840271585),
#  ('HIG', 0.0029605514437527347),
#  ('ADP', 0.0029633002829188015),
#  ('IBM', 0.0029751272654117145),
#  ('ESS', 0.003035059656633976),
#  ('AFL', 0.003179746339521561),
#  ('ATO', 0.0032532566547756048),
#  ('IFF', 0.0033128344995922987),
#  ('F', 0.0033192301371403055),
#  ('T', 0.003673677443331247),
#  ('FRT', 0.0037018610995751544),
#  ('CHTR', 0.004337666357620229),
#  ('JCI', 0.0043496247626020335),
#  ('GWW', 0.004372961161421607),
#  ('KR', 0.004406426389914397),
#  ('VMC', 0.004420733040674918),
#  ('PG', 0.004558381633892772),
#  ('SRE', 0.004589153541990854),
#  ('GRMN', 0.004633913892561736),
#  ('WFC', 0.004698804114312338),
#  ('PKG', 0.004727378860284404),
#  ('MAA', 0.005149486334139475),
#  ('SBAC', 0.0051690392478116465),
#  ('KMB', 0.0052129688850461875),
#  ('AXP', 0.005353239771643814),
#  ('PNW', 0.005354153283460228),
#  ('ULTA', 0.005491788495056049),
#  ('CMI', 0.005522647998638774),
#  ('ZTS', 0.00563449357913548),
#  ('AEP', 0.00589175978556522),
#  ('AVY', 0.006019166928929565),
#  ('UDR', 0.006139818991768742),
#  ('MSCI', 0.006150920087645062),
#  ('GIS', 0.006232057666262669),
#  ('SJM', 0.006340351215373907),
#  ('ETR', 0.006342709178560391),
#  ('CELG', 0.00638055311254071),
#  ('YUM', 0.006404078783887712),
#  ('CTAS', 0.006443447380251044),
#  ('CCI', 0.006580424148572739),
#  ('JEC', 0.006612828667122983),
#  ('DHR', 0.0066544579267544535),
#  ('AVB', 0.006699227428849319),
#  ('MMC', 0.006866045876149585),
#  ('ARE', 0.006902422818124698),
#  ('COG', 0.006906939358380715),
#  ('PAYX', 0.0069974512647767995),
#  ('PBCT', 0.007015659723602852),
#  ('TPR', 0.007282693547093988),
#  ('ED', 0.007393633449256143),
#  ('AAL', 0.007893496721934401),
#  ('CFG', 0.008003202130435927),
#  ('ALLE', 0.008109306674736416),
#  ('TRV', 0.008177405420425998),
#  ('ADM', 0.00848480915172356),
#  ('AMT', 0.008531866733474835),
#  ('L', 0.008588517576780141),
#  ('DRE', 0.008852798961994868),
#  ('DUK', 0.009075537113466758),
#  ('EQR', 0.009206762346541275),
#  ('ADS', 0.009209463065733559),
#  ('AWK', 0.009223723288123153),
#  ('SCHW', 0.009380804373014584),
#  ('INFO', 0.00946607316208592),
#  ('CHD', 0.009608011884977508),
#  ('HPQ', 0.009739453489559846),
#  ('XOM', 0.009973892704393528),
#  ('NTRS', 0.010228249268752876),
#  ('IR', 0.010844490336866741),
#  ('EBAY', 0.010930461359946797),
#  ('VRSK', 0.010944349682078247),
#  ('GPN', 0.011051196422660503),
#  ('MDLZ', 0.01111120933430687),
#  ('PSA', 0.011255827837031163),
#  ('HSY', 0.011268608771374922),
#  ('BK', 0.011274422980360743),
#  ('BBY', 0.01143991468721417),
#  ('CB', 0.012034429011234415),
#  ('OKE', 0.012258605578858273),
#  ('PM', 0.012331764037074144),
#  ('IRM', 0.012606904203302793),
#  ('ECL', 0.012978929051989496),
#  ('NEE', 0.013013106024426513),
#  ('HD', 0.013327955205173048),
#  ('NDAQ', 0.013414097021311022),
#  ('FOXA', 0.013472767112248984),
#  ('SLG', 0.013477386956121329),
#  ('EIX', 0.013543451628558856),
#  ('CPB', 0.013552183863767109),
#  ('FOX', 0.013635138393613744),
#  ('RSG', 0.01373648653208992),
#  ('TMK', 0.013816054753558404),
#  ('MCO', 0.013840223943146768),
#  ('KHC', 0.013913111597732897),
#  ('NCLH', 0.014067212316381195),
#  ('INTU', 0.014442164787984879),
#  ('AES', 0.014555875995313272),
#  ('SYF', 0.014601544081427331),
#  ('CCL', 0.014718924636288211),
#  ('AON', 0.014780122120888528),
#  ('HRB', 0.014895834491953419),
#  ('SNPS', 0.014921597658148045),
#  ('ROP', 0.015252983537554776),
#  ('REG', 0.015596129095469813),
#  ('SPGI', 0.015642581016358292),
#  ('ALL', 0.015658661824650366),
#  ('CL', 0.01573269931282617),
#  ('COST', 0.016277670175573355),
#  ('CLX', 0.01631871462252832),
#  ('XRX', 0.01633520410790723),
#  ('EXC', 0.01654907012390039),
#  ('AJG', 0.016618113664339518),
#  ('KMI', 0.016911193678792014),
#  ('MSI', 0.01704980462769612),
#  ('COF', 0.017061381282902133),
#  ('NOC', 0.017242550638719933),
#  ('DFS', 0.017256112780361654),
#  ('UPS', 0.017378310442703437),
#  ('MTB', 0.01749493972053795),
#  ('EFX', 0.017531984746437246),
#  ('GOOG', 0.017775686101653143),
#  ('CERN', 0.01781899581986135),
#  ('GLW', 0.017921340489274407),
#  ('IT', 0.01816537779198324),
#  ('ITW', 0.018238407098526643),
#  ('FTV', 0.018340012646000048),
#  ('MLM', 0.01834637956117735),
#  ('FRC', 0.018406405304376428),
#  ('CPRT', 0.018411751623507833),
#  ('DOV', 0.018486439470255966),
#  ('AMZN', 0.018499683331879346),
#  ('VFC', 0.018524717808183766),
#  ('USB', 0.01870271115532196),
#  ('HBAN', 0.018764265154805226),
#  ('JNJ', 0.018836136811148485),
#  ('CHRW', 0.019243450890511937),
#  ('WY', 0.01933320136776251),
#  ('VRSN', 0.019443754821424797),
#  ('TSS', 0.019487490603749436),
#  ('CAT', 0.0195984802971223),
#  ('ORCL', 0.019669059553250712),
#  ('ZION', 0.019698332229234783),
#  ('D', 0.019823462983663553),
#  ('SEE', 0.02001909720752071),
#  ('CDNS', 0.02001938068960385),
#  ('CTL', 0.020151953474777606),
#  ('WU', 0.02054079988713653),
#  ('GPS', 0.020602878964578686),
#  ('ETN', 0.020649861626482746),
#  ('CPRI', 0.020781033198475463),
#  ('WMB', 0.020798777645550715),
#  ('KO', 0.021135740738183806),
#  ('ICE', 0.021186783667325848),
#  ('CMCSA', 0.02121277216756301),
#  ('PEP', 0.02174937640649688),
#  ('TJX', 0.021833292074864286),
#  ('WM', 0.021841141788461194),
#  ('SHW', 0.0219381856796943),
#  ('NFLX', 0.022072400928515812),
#  ('ETFC', 0.022346968508492715),
#  ('NUE', 0.022433961563432803),
#  ('GOOGL', 0.022505075141458164),
#  ('KSU', 0.02283916000485231),
#  ('WLTW', 0.02297828173132377),
#  ('PRGO', 0.023467102930312844),
#  ('CBRE', 0.02369729568154222),
#  ('SIVB', 0.02379342418381647),
#  ('LOW', 0.023896618414160464),
#  ('APH', 0.02404860867944869),
#  ('CINF', 0.024102844941569224),
#  ('PH', 0.024113284680680636),
#  ('EXR', 0.024167973679427135),
#  ('SNA', 0.024193609756657075),
#  ('GS', 0.024249804234638184),
#  ('MA', 0.024493848020574305),
#  ('WHR', 0.024799848406733105),
#  ('HON', 0.025113917161235122),
#  ('COP', 0.02516551350927898),
#  ('PPG', 0.02523726205073107),
#  ('IPG', 0.02529667039290473),
#  ('CTXS', 0.025385157411197845),
#  ('FDX', 0.025408530888358705),
#  ('DISH', 0.025645582058478222),
#  ('AME', 0.025648222889655514),
#  ('RHI', 0.025718451154062016),
#  ('CRM', 0.025790712029413854),
#  ('ROST', 0.02594646597014716),
#  ('FLIR', 0.02600068539181022),
#  ('BBT', 0.026077292717731737),
#  ('CMA', 0.026217543415449462),
#  ('UNM', 0.026359008895003644),
#  ('MAR', 0.02654448359171102),
#  ('TAP', 0.026590692155593842),
#  ('ATVI', 0.026656981571113736),
#  ('NSC', 0.02711937608850512),
#  ('LIN', 0.027280379945730182),
#  ('UNP', 0.027616952481443136),
#  ('XLNX', 0.027751419314391512),
#  ('CSX', 0.02860591133212953),
#  ('V', 0.02877113609867621),
#  ('PHM', 0.029116053385277674),
#  ('TSCO', 0.02926846076248868),
#  ('FLS', 0.029576256683430113),
#  ('PFG', 0.029624101818269466),
#  ('BXP', 0.029809698139733776),
#  ('LEN', 0.03046398061299138),
#  ('STI', 0.030479521103528917),
#  ('XEC', 0.030573882367457728),
#  ('LMT', 0.030592395760093538),
#  ('TIF', 0.03081690262978576),
#  ('QRVO', 0.030856400162503128),
#  ('ANSS', 0.03096435316150359),
#  ('JEF', 0.031016367207111983),
#  ('UAA', 0.031099064281805866),
#  ('PYPL', 0.03112928968615325),
#  ('APD', 0.03114675620109164),
#  ('BAC', 0.03119237007870801),
#  ('VNO', 0.03135222717687647),
#  ('ADBE', 0.031908759631725125),
#  ('PNC', 0.03221034012111623),
#  ('AVGO', 0.03251659682072461),
#  ('LEG', 0.032707466508040905),
#  ('LB', 0.0328821507067234),
#  ('BEN', 0.03295739780567697),
#  ('LUV', 0.03304559091789594),
#  ('HBI', 0.03323561383744256),
#  ('ACN', 0.033391736027639674),
#  ('PLD', 0.03340026942596186),
#  ('EL', 0.03386669512793805),
#  ('FB', 0.033962300444907),
#  ('GM', 0.03410982087587788),
#  ('ALK', 0.03426849162671264),
#  ('WAB', 0.034302786127132556),
#  ('AAPL', 0.03445260882514578),
#  ('PCAR', 0.034520813442846965),
#  ('UA', 0.034589286618542214),
#  ('STT', 0.0347711211695092),
#  ('LNC', 0.034832748801243874),
#  ('BA', 0.03484963870582547),
#  ('O', 0.03486316025525671),
#  ('BHGE', 0.03513383127757974),
#  ('IVZ', 0.03577346841132423),
#  ('NRG', 0.035861247723669276),
#  ('WCG', 0.03636297346875139),
#  ('FLT', 0.03641220377129173),
#  ('NVDA', 0.036415914617596634),
#  ('DG', 0.036665452498020557),
#  ('DHI', 0.038130172970878284),
#  ('AOS', 0.0383179576622128),
#  ('ADI', 0.038481023447028306),
#  ('HPE', 0.03898014071771039),
#  ('EMR', 0.03898202766773817),
#  ('LRCX', 0.039135080851690596),
#  ('EXPE', 0.039160753999488485),
#  ('XYL', 0.03922897825144034),
#  ('BR', 0.03984584333843788),
#  ('MAT', 0.03991231192036926),
#  ('K', 0.04083685371817847),
#  ('OMC', 0.04092564500919593),
#  ('NWS', 0.04143880301927627),
#  ('UTX', 0.04144887507488004),
#  ('TROW', 0.04155449587055138),
#  ('TWTR', 0.04212147718823944),
#  ('SWK', 0.04226785966209867),
#  ('SLB', 0.04231868892044277),
#  ('RJF', 0.04259566207572085),
#  ('NWSA', 0.04295762259834479),
#  ('MPC', 0.04297874891681985),
#  ('INTC', 0.0429966527293435),
#  ('VIAB', 0.043457134020071564),
#  ('CE', 0.04353945311121343),
#  ('AKAM', 0.04402421831015424),
#  ('AMP', 0.04420931333272993),
#  ('GD', 0.044539945606354436),
#  ('NOV', 0.045341819593565535),
#  ('MU', 0.045367104951808734),
#  ('NLSN', 0.046834666014014203),
#  ('JPM', 0.04691624358232005),
#  ('ADSK', 0.04828160603305687),
#  ('NKE', 0.04831968328582725),
#  ('ROK', 0.048379755935551216),
#  ('C', 0.0485878707789178),
#  ('PWR', 0.048623409392221095),
#  ('TXT', 0.048696080400691066),
#  ('M', 0.0489515908303213),
#  ('BLK', 0.048951903626430315),
#  ('UAL', 0.04941385931331155),
#  ('HAS', 0.05003757514420215),
#  ('STZ', 0.05008232771095322),
#  ('JKHY', 0.05052402677900947),
#  ('MS', 0.05058631043420814),
#  ('HP', 0.05064961345302699),
#  ('DE', 0.05074355147719345),
#  ('TXN', 0.051238926705172716),
#  ('HOG', 0.05202753335972066),
#  ('PGR', 0.0528246029022057),
#  ('NTAP', 0.05361537127625571),
#  ('TEL', 0.05389072089205005),
#  ('DISCA', 0.054059892439135115),
#  ('RL', 0.05483297559109257),
#  ('BKNG', 0.055126819597377086),
#  ('EXPD', 0.055329018521494966),
#  ('DLTR', 0.05539140982629398),
#  ('SWKS', 0.05552611955968434),
#  ('LYB', 0.05585926336955094),
#  ('DXC', 0.056373573677864997),
#  ('JNPR', 0.05647466541869228),
#  ('DISCK', 0.05689373719540347),
#  ('PRU', 0.05714886409412667),
#  ('LKQ', 0.05739833095088542),
#  ('DAL', 0.057799006411020315),
#  ('PSX', 0.057941832970902496),
#  ('FFIV', 0.057956770324679496),
#  ('HII', 0.05820163595388106),
#  ('KSS', 0.05949763269286734),
#  ('MXIM', 0.05993093789683979),
#  ('CBS', 0.060744237807213164),
#  ('HES', 0.0630869897816897),
#  ('KMX', 0.06384381408494644),
#  ('CF', 0.06426403508350953),
#  ('FL', 0.06465437209574842),
#  ('DIS', 0.06483925532239354),
#  ('SYMC', 0.06822015927208813),
#  ('HFC', 0.06866794198210346),
#  ('URI', 0.06921837536929054),
#  ('EMN', 0.07000705122050288),
#  ('AMAT', 0.07273471631064865),
#  ('FAST', 0.0754029428473082),
#  ('MGM', 0.07629401144602133),
#  ('FANG', 0.07659359696522294),
#  ('KLAC', 0.07913664020875188),
#  ('WDC', 0.08313819250873689),
#  ('BWA', 0.08537103472208907),
#  ('MOS', 0.08563522573368632),
#  ('VLO', 0.08609830416325348),
#  ('CXO', 0.08708036186962165),
#  ('DVN', 0.09032629652531599),
#  ('FTI', 0.09054901336612176),
#  ('MCHP', 0.09167284754948835),
#  ('AMD', 0.09175888939206622),
#  ('DOW', 0.09540603935907166),
#  ('PVH', 0.09884133282464092),
#  ('EOG', 0.09971514660378578),
#  ('HAL', 0.10082300837691305),
#  ('APTV', 0.10134248848733218),
#  ('CAG', 0.10251562432870598),
#  ('WYNN', 0.10579916358325026),
#  ('MYL', 0.1073917836246383),
#  ('APA', 0.10998432290158755),
#  ('MRO', 0.11579764888820154),
#  ('FTNT', 0.1163375366794428),
#  ('FCX', 0.11770886755611043),
#  ('IPGP', 0.12008893493438944),
#  ('ANET', 0.12027697348454502),
#  ('PXD', 0.13029649917583264),
#  ('DWDP', 0.14379600641069645),
#  ('NBL', 0.14422315951192477),
#  ('AMG', 0.15940560638216805),
#  ('CTSH', 0.17397722812989347),
#  ('FLR', 0.27371442818901626)]
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=-80.0, marketPrice=10.29399965, marketValue=-823.52, averageCost=10.22876875, unrealizedPNL=-5.22, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=20.0, marketPrice=50.5400009, marketValue=1010.8, averageCost=50.7085, unrealizedPNL=-3.37, realizedPNL=-0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.4797058, marketValue=-1252.4, averageCost=253.79642, unrealizedPNL=16.58, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=270639, symbol='INTC', exchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, avgCost=0.0)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='000154a9.5cd17d49.01.01', commission=1.023306, currency='USD', realizedPNL=-4.293306)
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.54390335, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.4669342, marketValue=-1252.33, averageCost=253.79642, unrealizedPNL=16.65, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.5560951, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.5322113, marketValue=-1252.66, averageCost=253.79642, unrealizedPNL=16.32, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=7516, symbol='GE', exchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, avgCost=0.0)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='00010f11.5cd182e2.01.01', commission=1.0, currency='USD', realizedPNL=-6.2985)
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.29399965, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=-5.0, marketPrice=250.5348053, marketValue=-1252.67, averageCost=253.79642, unrealizedPNL=16.31, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=76792991, symbol='TSLA', exchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, avgCost=0.0)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='00018d32.5cd18287.01.01', commission=1.0, currency='USD', realizedPNL=14.9321)
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.55815125, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.4960022, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.44322205, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=11218575, symbol='FLR', exchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=11218575, symbol='FLR', exchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=11218575, symbol='FLR', exchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, avgCost=29.15)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='0000fda5.5cd15e50.01.01', commission=1.0, currency='USD')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.1420002, marketValue=874.26, averageCost=29.18333335, unrealizedPNL=-1.24, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.52399825, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.1499996, marketValue=874.5, averageCost=29.18333335, unrealizedPNL=-1.0, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.3888092, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=4728759, symbol='CTSH', exchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=4728759, symbol='CTSH', exchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=4728759, symbol='CTSH', exchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, avgCost=57.96)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='00010fc2.5cd17fb5.01.01', commission=1.0, currency='USD')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.5299988, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.95399855, marketValue=869.31, averageCost=58.02666665, unrealizedPNL=-1.09, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.15999985, marketValue=874.8, averageCost=29.18333335, unrealizedPNL=-0.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.51599885, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.9239998, marketValue=868.86, averageCost=58.02666665, unrealizedPNL=-1.54, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.14855575, marketValue=874.46, averageCost=29.18333335, unrealizedPNL=-1.04, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.29655455, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=13878278, symbol='CNC', exchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=13878278, symbol='CNC', exchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=13878278, symbol='CNC', exchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, avgCost=55.31000000000001)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='0000e634.5cd156ee.01.01', commission=1.018959, currency='USD')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.1507683, marketValue=874.52, averageCost=29.18333335, unrealizedPNL=-0.98, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.33390045, marketValue=-830.01, averageCost=55.2420694, unrealizedPNL=-1.38, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.5340004, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.88666155, marketValue=868.3, averageCost=58.02666665, unrealizedPNL=-2.1, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.17502215, marketValue=875.25, averageCost=29.18333335, unrealizedPNL=-0.25, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.29915235, marketValue=-829.49, averageCost=55.2420694, unrealizedPNL=-0.86, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.25479125, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=10627, symbol='NWL', exchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=10627, symbol='NWL', exchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=10627, symbol='NWL', exchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, avgCost=16.18)
# ERROR:ib_insync.wrapper:commissionReport: No execution found for CommissionReport(execId='0000d6a5.5cd19dcb.01.01', commission=1.022696, currency='USD')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.18390465, marketValue=-809.2, averageCost=16.15954605, unrealizedPNL=-1.22, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=10627, symbol='NWL', exchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, avgCost=16.15954605)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=11218575, symbol='FLR', exchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, avgCost=29.18333335)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=13878278, symbol='CNC', exchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, avgCost=55.2420694)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=270639, symbol='INTC', exchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=7516, symbol='GE', exchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=76792991, symbol='TSLA', exchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=4728759, symbol='CTSH', exchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, avgCost=58.02666665)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=76792991, symbol='TSLA', exchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=10627, symbol='NWL', exchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, avgCost=16.15954605)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=11218575, symbol='FLR', exchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, avgCost=29.18333335)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=7516, symbol='GE', exchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=13878278, symbol='CNC', exchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, avgCost=55.2420694)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=4728759, symbol='CTSH', exchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, avgCost=58.02666665)
# INFO:ib_insync.wrapper:position: Position(account='U2578504', contract=Stock(conId=270639, symbol='INTC', exchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, avgCost=0.0)
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.2760954, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.16600035, marketValue=-808.3, averageCost=16.15954605, unrealizedPNL=-0.32, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.4560013, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.84386445, marketValue=867.66, averageCost=58.02666665, unrealizedPNL=-2.74, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.20599935, marketValue=876.18, averageCost=29.18333335, unrealizedPNL=0.68, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.09999845, marketValue=-826.5, averageCost=55.2420694, unrealizedPNL=2.13, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=249.8570862, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.2659998, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.12999915, marketValue=-806.5, averageCost=16.15954605, unrealizedPNL=1.48, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.4300003, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.80399705, marketValue=867.06, averageCost=58.02666665, unrealizedPNL=-3.34, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.17985725, marketValue=875.4, averageCost=29.18333335, unrealizedPNL=-0.1, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.26399995, marketValue=-828.96, averageCost=55.2420694, unrealizedPNL=-0.33, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=249.55000305, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.28399945, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.09600065, marketValue=-804.8, averageCost=16.15954605, unrealizedPNL=3.18, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.45000075, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.7799988, marketValue=866.7, averageCost=58.02666665, unrealizedPNL=-3.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.25, marketValue=877.5, averageCost=29.18333335, unrealizedPNL=2.0, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.44743345, marketValue=-831.71, averageCost=55.2420694, unrealizedPNL=-3.08, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.43948365, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.2659998, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.05399895, marketValue=-802.7, averageCost=16.15954605, unrealizedPNL=5.28, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.4339981, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.78643035, marketValue=866.8, averageCost=58.02666665, unrealizedPNL=-3.6, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.21188165, marketValue=876.36, averageCost=29.18333335, unrealizedPNL=0.86, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.4464073, marketValue=-831.7, averageCost=55.2420694, unrealizedPNL=-3.07, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.75971985, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.04599955, marketValue=-802.3, averageCost=16.15954605, unrealizedPNL=5.68, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.7840004, marketValue=866.76, averageCost=58.02666665, unrealizedPNL=-3.64, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.19799995, marketValue=875.94, averageCost=29.18333335, unrealizedPNL=0.44, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.3726082, marketValue=-830.59, averageCost=55.2420694, unrealizedPNL=-1.96, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.7219696, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.0300007, marketValue=-801.5, averageCost=16.15954605, unrealizedPNL=6.48, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.36600115, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.70000075, marketValue=865.5, averageCost=58.02666665, unrealizedPNL=-4.9, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.12509345, marketValue=873.75, averageCost=29.18333335, unrealizedPNL=-1.75, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.34999845, marketValue=-830.25, averageCost=55.2420694, unrealizedPNL=-1.62, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=250.96328735, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.2840004, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=16.0340004, marketValue=-801.7, averageCost=16.15954605, unrealizedPNL=6.28, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=57.6739998, marketValue=865.11, averageCost=58.02666665, unrealizedPNL=-5.29, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.15399935, marketValue=874.62, averageCost=29.18333335, unrealizedPNL=-0.88, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.4960022, marketValue=-832.44, averageCost=55.2420694, unrealizedPNL=-3.81, realizedPNL=0.0, account='U2578504')
# ...
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.4935913, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.4400711, marketValue=876.6, averageCost=58.02666665, unrealizedPNL=6.2, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.5300007, marketValue=885.9, averageCost=29.18333335, unrealizedPNL=10.4, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.91999815, marketValue=-838.8, averageCost=55.2420694, unrealizedPNL=-10.17, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.8699951, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.1199999, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=15.9700012, marketValue=-798.5, averageCost=16.15954605, unrealizedPNL=9.48, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.47999955, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.47999955, marketValue=877.2, averageCost=58.02666665, unrealizedPNL=6.8, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.5400009, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.52000425, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.1199999, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=15.97679235, marketValue=-798.84, averageCost=16.15954605, unrealizedPNL=9.14, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.5699997, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.52000045, marketValue=877.8, averageCost=58.02666665, unrealizedPNL=7.4, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.539999, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.856369, marketValue=-837.85, averageCost=55.2420694, unrealizedPNL=-9.21, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.23999025, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.1199999, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.5699997, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.5099983, marketValue=877.65, averageCost=58.02666665, unrealizedPNL=7.25, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.539999, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.3999939, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.1199999, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.3999939, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.14000035, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=15.97679235, marketValue=-798.84, averageCost=16.15954605, unrealizedPNL=9.14, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=270639, symbol='INTC', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='INTC', tradingClass='NMS'), position=0.0, marketPrice=50.54999925, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-4.29, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.5099983, marketValue=877.65, averageCost=58.02666665, unrealizedPNL=7.25, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.539999, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.3999939, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.54999925, marketValue=878.25, averageCost=58.02666665, unrealizedPNL=7.85, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.48999025, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=10627, symbol='NWL', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='NWL', tradingClass='NMS'), position=-50.0, marketPrice=15.97679235, marketValue=-798.84, averageCost=16.15954605, unrealizedPNL=9.14, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.539999, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.2200012, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=4728759, symbol='CTSH', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='CTSH', tradingClass='NMS'), position=15.0, marketPrice=58.56000135, marketValue=878.4, averageCost=58.02666665, unrealizedPNL=8.0, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=11218575, symbol='FLR', right='0', primaryExchange='NYSE', currency='USD', localSymbol='FLR', tradingClass='FLR'), position=30.0, marketPrice=29.539999, marketValue=886.2, averageCost=29.18333335, unrealizedPNL=10.7, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.2200012, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=7516, symbol='GE', right='0', primaryExchange='NYSE', currency='USD', localSymbol='GE', tradingClass='GE'), position=0.0, marketPrice=10.14000035, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=-6.3, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=13878278, symbol='CNC', right='0', primaryExchange='NYSE', currency='USD', localSymbol='CNC', tradingClass='CNC'), position=-15.0, marketPrice=55.84999845, marketValue=-837.75, averageCost=55.2420694, unrealizedPNL=-9.12, realizedPNL=0.0, account='U2578504')
# INFO:ib_insync.wrapper:updatePortfolio: PortfolioItem(contract=Stock(conId=76792991, symbol='TSLA', right='0', primaryExchange='NASDAQ', currency='USD', localSymbol='TSLA', tradingClass='NMS'), position=0.0, marketPrice=247.22999575, marketValue=0.0, averageCost=0.0, unrealizedPNL=0.0, realizedPNL=14.93, account='U2578504')
